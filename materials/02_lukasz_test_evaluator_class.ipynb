# %%
import os


from evaluate import ClusteringEvaluator
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_path = os.path.join("..", "clustering-data-v1")
data_path = os.path.abspath(data_path)
ce = ClusteringEvaluator(data_path=data_path)
display(ce.results_df)
ce.do_all("sipu", "compound", plot=True)
display(ce.results_df)
# Out:
# Empty DataFrame
# Columns: [battery, dataset, method, labels, n_clusters, rand_score, silhouette_score, NCA]
# Index: []
# Loaded data for sipu - compound
# /Users/mat/opt/anaconda3/envs/asseco/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/mat/opt/anaconda3/envs/asseco/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/mat/opt/anaconda3/envs/asseco/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/mat/opt/anaconda3/envs/asseco/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/mat/opt/anaconda3/envs/asseco/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#    battery   dataset         method   labels  n_clusters  rand_score
# 0     sipu  compound         kmeans  labels0           6    0.537865  \
# 1     sipu  compound         kmeans  labels1           4    0.738828
# 2     sipu  compound         kmeans  labels2           5    0.582999
# 3     sipu  compound         kmeans  labels3           4    0.596489
# 4     sipu  compound         kmeans  labels4           5    0.742807
# 5     sipu  compound         dbscan  labels0           6    0.885321
# 6     sipu  compound         dbscan  labels1           4    0.748004
# 7     sipu  compound         dbscan  labels2           5    0.887956
# 8     sipu  compound         dbscan  labels3           4    0.836519
# 9     sipu  compound         dbscan  labels4           5    0.794337
# 10    sipu  compound  agglomerative  labels0           6    0.550577
# 11    sipu  compound  agglomerative  labels1           4    0.879290
# 12    sipu  compound  agglomerative  labels2           5    0.585487
# 13    sipu  compound  agglomerative  labels3           4    0.737443
# 14    sipu  compound  agglomerative  labels4           5    0.761713
# 15    sipu  compound  agglomerative  labels0           6    0.742481
# 16    sipu  compound  agglomerative  labels1           4    0.925356
# 17    sipu  compound  agglomerative  labels2           5    0.741496
# 18    sipu  compound  agglomerative  labels3           4    0.794270
# 19    sipu  compound  agglomerative  labels4           5    0.871486
# 20    sipu  compound  agglomerative  labels0           6    0.792878
# 21    sipu  compound  agglomerative  labels1           4    0.851878
# 22    sipu  compound  agglomerative  labels2           5    0.796298
# 23    sipu  compound  agglomerative  labels3           4    0.828137
# 24    sipu  compound  agglomerative  labels4           5    0.757881
# 25    sipu  compound  agglomerative  labels0           6    0.803026
# 26    sipu  compound  agglomerative  labels1           4    0.909666
# 27    sipu  compound  agglomerative  labels2           5    0.765497
# 28    sipu  compound  agglomerative  labels3           4    0.798372
# 29    sipu  compound  agglomerative  labels4           5    0.803169
# 30    sipu  compound          genie  labels0           6    0.565935
# 31    sipu  compound          genie  labels1           4    0.775595
# 32    sipu  compound          genie  labels2           5    0.521087
# 33    sipu  compound          genie  labels3           4    0.611531
# 34    sipu  compound          genie  labels4           5    0.569824
# 35    sipu  compound          genie  labels0           6    0.541257
# 36    sipu  compound          genie  labels1           4    0.775595
# 37    sipu  compound          genie  labels2           5    0.583866
# 38    sipu  compound          genie  labels3           4    0.611531
# 39    sipu  compound          genie  labels4           5    0.760048
# 40    sipu  compound          genie  labels0           6    0.607345
# 41    sipu  compound          genie  labels1           4    0.879882
# 42    sipu  compound          genie  labels2           5    0.703997
# 43    sipu  compound          genie  labels3           4    0.738108
# 44    sipu  compound          genie  labels4           5    0.856762
# 45    sipu  compound          genie  labels0           6    0.754603
# 46    sipu  compound          genie  labels1           4    0.913517
# 47    sipu  compound          genie  labels2           5    0.747218
# 48    sipu  compound          genie  labels3           4    0.797245
# 49    sipu  compound          genie  labels4           5    0.847201
# 50    sipu  compound          genie  labels0           6    0.742481
# 51    sipu  compound          genie  labels1           4    0.925356
# 52    sipu  compound          genie  labels2           5    0.741496
# 53    sipu  compound          genie  labels3           4    0.794270
# 54    sipu  compound          genie  labels4           5    0.871486
#
#     silhouette_score       NCA   params  eps  min_samples   linkage
# 0           0.431712  0.681044  default  NaN          NaN       NaN  \
# 1           0.499872  0.670342  default  NaN          NaN       NaN
# 2           0.524247  0.652532  default  NaN          NaN       NaN
# 3           0.499751  0.506634  default  NaN          NaN       NaN
# 4           0.524247  0.810383  default  NaN          NaN       NaN
# 5           0.457218  0.767556  default  0.2          5.0       NaN
# 6           0.457218  0.409101  default  0.2          5.0       NaN
# 7           0.457218  0.772000  default  0.2          5.0       NaN
# 8           0.457218  0.597530  default  0.2          5.0       NaN
# 9           0.457218  0.674296  default  0.2          5.0       NaN
# 10          0.417544  0.736523  default  NaN          NaN      ward
# 11          0.549850  0.502008  default  NaN          NaN      ward
# 12          0.509904  0.696490  default  NaN          NaN      ward
# 13          0.549850  0.376506  default  NaN          NaN      ward
# 14          0.509904  0.870613  default  NaN          NaN      ward
# 15          0.359442  0.404000  default  NaN          NaN    single
# 16          0.420870  0.664319  default  NaN          NaN    single
# 17          0.370101  0.404000  default  NaN          NaN    single
# 18          0.420870  0.505000  default  NaN          NaN    single
# 19          0.370101  0.496479  default  NaN          NaN    single
# 20          0.453223  0.460000  default  NaN          NaN  complete
# 21          0.476368  0.615023  default  NaN          NaN  complete
# 22          0.458974  0.488000  default  NaN          NaN  complete
# 23          0.476368  0.610000  default  NaN          NaN  complete
# 24          0.458974  0.440141  default  NaN          NaN  complete
# 25          0.460774  0.642222  default  NaN          NaN   average
# 26          0.459079  0.654930  default  NaN          NaN   average
# 27          0.466005  0.460000  default  NaN          NaN   average
# 28          0.459079  0.525000  default  NaN          NaN   average
# 29          0.466005  0.464789  default  NaN          NaN   average
# 30          0.339752  0.753578  default  NaN          NaN       NaN
# 31          0.432129  0.839662  default  NaN          NaN       NaN
# 32          0.298083  0.558841  default  NaN          NaN       NaN
# 33          0.432129  0.629747  default  NaN          NaN       NaN
# 34          0.298083  0.559324  default  NaN          NaN       NaN
# 35          0.429951  0.698534  default  NaN          NaN       NaN
# 36          0.432129  0.839662  default  NaN          NaN       NaN
# 37          0.455819  0.693541  default  NaN          NaN       NaN
# 38          0.432129  0.629747  default  NaN          NaN       NaN
# 39          0.455819  0.866926  default  NaN          NaN       NaN
# 40          0.359039  0.626382  default  NaN          NaN       NaN
# 41          0.557979  0.518072  default  NaN          NaN       NaN
# 42          0.409671  0.611263  default  NaN          NaN       NaN
# 43          0.557979  0.388554  default  NaN          NaN       NaN
# 44          0.409671  0.764078  default  NaN          NaN       NaN
# 45          0.424534  0.424000  default  NaN          NaN       NaN
# 46          0.459874  0.657277  default  NaN          NaN       NaN
# 47          0.412401  0.416000  default  NaN          NaN       NaN
# 48          0.459874  0.520000  default  NaN          NaN       NaN
# 49          0.412401  0.485915  default  NaN          NaN       NaN
# 50          0.359442  0.404000  default  NaN          NaN       NaN
# 51          0.420870  0.664319  default  NaN          NaN       NaN
# 52          0.370101  0.404000  default  NaN          NaN       NaN
# 53          0.420870  0.505000  default  NaN          NaN       NaN
# 54          0.370101  0.496479  default  NaN          NaN       NaN
#
#     gini_threshold
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# 30             0.1
# 31             0.1
# 32             0.1
# 33             0.1
# 34             0.1
# 35             0.3
# 36             0.3
# 37             0.3
# 38             0.3
# 39             0.3
# 40             0.5
# 41             0.5
# 42             0.5
# 43             0.5
# 44             0.5
# 45             0.7
# 46             0.7
# 47             0.7
# 48             0.7
# 49             0.7
# 50             0.9
# 51             0.9
# 52             0.9
# 53             0.9
# 54             0.9

# %%
ce.evaluate_single_method(
    "sipu", "compound", "dbscan", plot=True, eps=0.2, min_samples=7
)
display(ce.results_df)
display(ce.results_df[ce.results_df["eps"] == 0.2])
# Out:
# clusterer: DBSCAN(eps=0.2, min_samples=7)
#    battery   dataset         method   labels  n_clusters  rand_score
# 0     sipu  compound         kmeans  labels0           6    0.537865  \
# 1     sipu  compound         kmeans  labels1           4    0.738828
# 2     sipu  compound         kmeans  labels2           5    0.582999
# 3     sipu  compound         kmeans  labels3           4    0.596489
# 4     sipu  compound         kmeans  labels4           5    0.742807
# 5     sipu  compound         dbscan  labels0           6    0.885321
# 6     sipu  compound         dbscan  labels1           4    0.748004
# 7     sipu  compound         dbscan  labels2           5    0.887956
# 8     sipu  compound         dbscan  labels3           4    0.836519
# 9     sipu  compound         dbscan  labels4           5    0.794337
# 10    sipu  compound  agglomerative  labels0           6    0.550577
# 11    sipu  compound  agglomerative  labels1           4    0.879290
# 12    sipu  compound  agglomerative  labels2           5    0.585487
# 13    sipu  compound  agglomerative  labels3           4    0.737443
# 14    sipu  compound  agglomerative  labels4           5    0.761713
# 15    sipu  compound  agglomerative  labels0           6    0.742481
# 16    sipu  compound  agglomerative  labels1           4    0.925356
# 17    sipu  compound  agglomerative  labels2           5    0.741496
# 18    sipu  compound  agglomerative  labels3           4    0.794270
# 19    sipu  compound  agglomerative  labels4           5    0.871486
# 20    sipu  compound  agglomerative  labels0           6    0.792878
# 21    sipu  compound  agglomerative  labels1           4    0.851878
# 22    sipu  compound  agglomerative  labels2           5    0.796298
# 23    sipu  compound  agglomerative  labels3           4    0.828137
# 24    sipu  compound  agglomerative  labels4           5    0.757881
# 25    sipu  compound  agglomerative  labels0           6    0.803026
# 26    sipu  compound  agglomerative  labels1           4    0.909666
# 27    sipu  compound  agglomerative  labels2           5    0.765497
# 28    sipu  compound  agglomerative  labels3           4    0.798372
# 29    sipu  compound  agglomerative  labels4           5    0.803169
# 30    sipu  compound          genie  labels0           6    0.565935
# 31    sipu  compound          genie  labels1           4    0.775595
# 32    sipu  compound          genie  labels2           5    0.521087
# 33    sipu  compound          genie  labels3           4    0.611531
# 34    sipu  compound          genie  labels4           5    0.569824
# 35    sipu  compound          genie  labels0           6    0.541257
# 36    sipu  compound          genie  labels1           4    0.775595
# 37    sipu  compound          genie  labels2           5    0.583866
# 38    sipu  compound          genie  labels3           4    0.611531
# 39    sipu  compound          genie  labels4           5    0.760048
# 40    sipu  compound          genie  labels0           6    0.607345
# 41    sipu  compound          genie  labels1           4    0.879882
# 42    sipu  compound          genie  labels2           5    0.703997
# 43    sipu  compound          genie  labels3           4    0.738108
# 44    sipu  compound          genie  labels4           5    0.856762
# 45    sipu  compound          genie  labels0           6    0.754603
# 46    sipu  compound          genie  labels1           4    0.913517
# 47    sipu  compound          genie  labels2           5    0.747218
# 48    sipu  compound          genie  labels3           4    0.797245
# 49    sipu  compound          genie  labels4           5    0.847201
# 50    sipu  compound          genie  labels0           6    0.742481
# 51    sipu  compound          genie  labels1           4    0.925356
# 52    sipu  compound          genie  labels2           5    0.741496
# 53    sipu  compound          genie  labels3           4    0.794270
# 54    sipu  compound          genie  labels4           5    0.871486
# 55    sipu  compound         dbscan  labels0           6    0.877279
# 56    sipu  compound         dbscan  labels1           4    0.728128
# 57    sipu  compound         dbscan  labels2           5    0.874815
# 58    sipu  compound         dbscan  labels3           4    0.827006
# 59    sipu  compound         dbscan  labels4           5    0.770806
#
#     silhouette_score       NCA   params  eps  min_samples   linkage
# 0           0.431712  0.681044  default  NaN          NaN       NaN  \
# 1           0.499872  0.670342  default  NaN          NaN       NaN
# 2           0.524247  0.652532  default  NaN          NaN       NaN
# 3           0.499751  0.506634  default  NaN          NaN       NaN
# 4           0.524247  0.810383  default  NaN          NaN       NaN
# 5           0.457218  0.767556  default  0.2          5.0       NaN
# 6           0.457218  0.409101  default  0.2          5.0       NaN
# 7           0.457218  0.772000  default  0.2          5.0       NaN
# 8           0.457218  0.597530  default  0.2          5.0       NaN
# 9           0.457218  0.674296  default  0.2          5.0       NaN
# 10          0.417544  0.736523  default  NaN          NaN      ward
# 11          0.549850  0.502008  default  NaN          NaN      ward
# 12          0.509904  0.696490  default  NaN          NaN      ward
# 13          0.549850  0.376506  default  NaN          NaN      ward
# 14          0.509904  0.870613  default  NaN          NaN      ward
# 15          0.359442  0.404000  default  NaN          NaN    single
# 16          0.420870  0.664319  default  NaN          NaN    single
# 17          0.370101  0.404000  default  NaN          NaN    single
# 18          0.420870  0.505000  default  NaN          NaN    single
# 19          0.370101  0.496479  default  NaN          NaN    single
# 20          0.453223  0.460000  default  NaN          NaN  complete
# 21          0.476368  0.615023  default  NaN          NaN  complete
# 22          0.458974  0.488000  default  NaN          NaN  complete
# 23          0.476368  0.610000  default  NaN          NaN  complete
# 24          0.458974  0.440141  default  NaN          NaN  complete
# 25          0.460774  0.642222  default  NaN          NaN   average
# 26          0.459079  0.654930  default  NaN          NaN   average
# 27          0.466005  0.460000  default  NaN          NaN   average
# 28          0.459079  0.525000  default  NaN          NaN   average
# 29          0.466005  0.464789  default  NaN          NaN   average
# 30          0.339752  0.753578  default  NaN          NaN       NaN
# 31          0.432129  0.839662  default  NaN          NaN       NaN
# 32          0.298083  0.558841  default  NaN          NaN       NaN
# 33          0.432129  0.629747  default  NaN          NaN       NaN
# 34          0.298083  0.559324  default  NaN          NaN       NaN
# 35          0.429951  0.698534  default  NaN          NaN       NaN
# 36          0.432129  0.839662  default  NaN          NaN       NaN
# 37          0.455819  0.693541  default  NaN          NaN       NaN
# 38          0.432129  0.629747  default  NaN          NaN       NaN
# 39          0.455819  0.866926  default  NaN          NaN       NaN
# 40          0.359039  0.626382  default  NaN          NaN       NaN
# 41          0.557979  0.518072  default  NaN          NaN       NaN
# 42          0.409671  0.611263  default  NaN          NaN       NaN
# 43          0.557979  0.388554  default  NaN          NaN       NaN
# 44          0.409671  0.764078  default  NaN          NaN       NaN
# 45          0.424534  0.424000  default  NaN          NaN       NaN
# 46          0.459874  0.657277  default  NaN          NaN       NaN
# 47          0.412401  0.416000  default  NaN          NaN       NaN
# 48          0.459874  0.520000  default  NaN          NaN       NaN
# 49          0.412401  0.485915  default  NaN          NaN       NaN
# 50          0.359442  0.404000  default  NaN          NaN       NaN
# 51          0.420870  0.664319  default  NaN          NaN       NaN
# 52          0.370101  0.404000  default  NaN          NaN       NaN
# 53          0.420870  0.505000  default  NaN          NaN       NaN
# 54          0.370101  0.496479  default  NaN          NaN       NaN
# 55          0.443863  0.745614   custom  0.2          7.0       NaN
# 56          0.443863  0.396374   custom  0.2          7.0       NaN
# 57          0.443863  0.740723   custom  0.2          7.0       NaN
# 58          0.443863  0.601506   custom  0.2          7.0       NaN
# 59          0.443863  0.621678   custom  0.2          7.0       NaN
#
#     gini_threshold
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# 30             0.1
# 31             0.1
# 32             0.1
# 33             0.1
# 34             0.1
# 35             0.3
# 36             0.3
# 37             0.3
# 38             0.3
# 39             0.3
# 40             0.5
# 41             0.5
# 42             0.5
# 43             0.5
# 44             0.5
# 45             0.7
# 46             0.7
# 47             0.7
# 48             0.7
# 49             0.7
# 50             0.9
# 51             0.9
# 52             0.9
# 53             0.9
# 54             0.9
# 55             NaN
# 56             NaN
# 57             NaN
# 58             NaN
# 59             NaN
#    battery   dataset  method   labels  n_clusters  rand_score
# 5     sipu  compound  dbscan  labels0           6    0.885321  \
# 6     sipu  compound  dbscan  labels1           4    0.748004
# 7     sipu  compound  dbscan  labels2           5    0.887956
# 8     sipu  compound  dbscan  labels3           4    0.836519
# 9     sipu  compound  dbscan  labels4           5    0.794337
# 55    sipu  compound  dbscan  labels0           6    0.877279
# 56    sipu  compound  dbscan  labels1           4    0.728128
# 57    sipu  compound  dbscan  labels2           5    0.874815
# 58    sipu  compound  dbscan  labels3           4    0.827006
# 59    sipu  compound  dbscan  labels4           5    0.770806
#
#     silhouette_score       NCA   params  eps  min_samples linkage
# 5           0.457218  0.767556  default  0.2          5.0     NaN  \
# 6           0.457218  0.409101  default  0.2          5.0     NaN
# 7           0.457218  0.772000  default  0.2          5.0     NaN
# 8           0.457218  0.597530  default  0.2          5.0     NaN
# 9           0.457218  0.674296  default  0.2          5.0     NaN
# 55          0.443863  0.745614   custom  0.2          7.0     NaN
# 56          0.443863  0.396374   custom  0.2          7.0     NaN
# 57          0.443863  0.740723   custom  0.2          7.0     NaN
# 58          0.443863  0.601506   custom  0.2          7.0     NaN
# 59          0.443863  0.621678   custom  0.2          7.0     NaN
#
#     gini_threshold
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 55             NaN
# 56             NaN
# 57             NaN
# 58             NaN
# 59             NaN

# %%
ce.save_results(filename="results.csv")
# Out:
# Results saved to results.csv
