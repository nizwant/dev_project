# %%
from evaluate import ClusteringEvaluator
# %load_ext autoreload
# %autoreload 2

# %%
ce = ClusteringEvaluator()
display(ce.results_df)
ce.do_all("sipu","compound", plot=True)
display(ce.results_df)
# Out:
# Empty DataFrame
# Columns: [battery, dataset, method, labels, n_clusters, rand_score, silhouette_score, NCA]
# Index: []
# Loaded data for sipu - compound
#    battery   dataset         method   labels  n_clusters  rand_score  \
# 0     sipu  compound         kmeans  labels0           6    0.539721
# 1     sipu  compound         kmeans  labels1           4    0.783095
# 2     sipu  compound         kmeans  labels2           5    0.486942
# 3     sipu  compound         kmeans  labels3           4    0.596352
# 4     sipu  compound         kmeans  labels4           5    0.835282
# 5     sipu  compound         dbscan  labels0           6    0.436617
# 6     sipu  compound         dbscan  labels1           4    0.584192
# 7     sipu  compound         dbscan  labels2           5    0.436478
# 8     sipu  compound         dbscan  labels3           4    0.476249
# 9     sipu  compound         dbscan  labels4           5    0.543696
# 10    sipu  compound  agglomerative  labels0           6    0.551803
# 11    sipu  compound  agglomerative  labels1           4    0.879290
# 12    sipu  compound  agglomerative  labels2           5    0.586619
# 13    sipu  compound  agglomerative  labels3           4    0.737443
# 14    sipu  compound  agglomerative  labels4           5    0.762757
# 15    sipu  compound  agglomerative  labels0           6    0.742481
# 16    sipu  compound  agglomerative  labels1           4    0.925356
# 17    sipu  compound  agglomerative  labels2           5    0.741496
# 18    sipu  compound  agglomerative  labels3           4    0.794270
# 19    sipu  compound  agglomerative  labels4           5    0.871486
# 20    sipu  compound  agglomerative  labels0           6    0.792878
# 21    sipu  compound  agglomerative  labels1           4    0.851878
# 22    sipu  compound  agglomerative  labels2           5    0.796298
# 23    sipu  compound  agglomerative  labels3           4    0.828137
# 24    sipu  compound  agglomerative  labels4           5    0.757881
# 25    sipu  compound  agglomerative  labels0           6    0.803026
# 26    sipu  compound  agglomerative  labels1           4    0.909666
# 27    sipu  compound  agglomerative  labels2           5    0.765497
# 28    sipu  compound  agglomerative  labels3           4    0.798372
# 29    sipu  compound  agglomerative  labels4           5    0.803169
# 30    sipu  compound          genie  labels0           6    0.565935
# 31    sipu  compound          genie  labels1           4    0.775595
# 32    sipu  compound          genie  labels2           5    0.521087
# 33    sipu  compound          genie  labels3           4    0.611531
# 34    sipu  compound          genie  labels4           5    0.569824
# 35    sipu  compound          genie  labels0           6    0.541257
# 36    sipu  compound          genie  labels1           4    0.775595
# 37    sipu  compound          genie  labels2           5    0.583866
# 38    sipu  compound          genie  labels3           4    0.611531
# 39    sipu  compound          genie  labels4           5    0.760048
# 40    sipu  compound          genie  labels0           6    0.607345
# 41    sipu  compound          genie  labels1           4    0.879882
# 42    sipu  compound          genie  labels2           5    0.703997
# 43    sipu  compound          genie  labels3           4    0.738108
# 44    sipu  compound          genie  labels4           5    0.856762
# 45    sipu  compound          genie  labels0           6    0.754603
# 46    sipu  compound          genie  labels1           4    0.913517
# 47    sipu  compound          genie  labels2           5    0.747218
# 48    sipu  compound          genie  labels3           4    0.797245
# 49    sipu  compound          genie  labels4           5    0.847201
# 50    sipu  compound          genie  labels0           6    0.742481
# 51    sipu  compound          genie  labels1           4    0.925356
# 52    sipu  compound          genie  labels2           5    0.741496
# 53    sipu  compound          genie  labels3           4    0.794270
# 54    sipu  compound          genie  labels4           5    0.871486
#
#     silhouette_score       NCA   params   linkage  gini_threshold
# 0           0.430090  0.673607  default       NaN             NaN
# 1           0.455494  0.530516  default       NaN             NaN
# 2           0.396344  0.485488  default       NaN             NaN
# 3           0.499777  0.511381  default       NaN             NaN
# 4           0.488060  0.705986  default       NaN             NaN
# 5           0.638323  0.200000  default       NaN             NaN
# 6           0.638323  0.333333  default       NaN             NaN
# 7           0.638323  0.200000  default       NaN             NaN
# 8           0.638323  0.250000  default       NaN             NaN
# 9           0.638323  0.250000  default       NaN             NaN
# 10          0.417080  0.737789  default      ward             NaN
# 11          0.549850  0.502008  default      ward             NaN
# 12          0.509396  0.697756  default      ward             NaN
# 13          0.549850  0.376506  default      ward             NaN
# 14          0.509396  0.872195  default      ward             NaN
# 15          0.359442  0.404000  default    single             NaN
# 16          0.420871  0.664319  default    single             NaN
# 17          0.370102  0.404000  default    single             NaN
# 18          0.420871  0.505000  default    single             NaN
# 19          0.370102  0.496479  default    single             NaN
# 20          0.453223  0.460000  default  complete             NaN
# 21          0.476368  0.615023  default  complete             NaN
# 22          0.458974  0.488000  default  complete             NaN
# 23          0.476368  0.610000  default  complete             NaN
# 24          0.458974  0.440141  default  complete             NaN
# 25          0.460774  0.642222  default   average             NaN
# 26          0.459079  0.654930  default   average             NaN
# 27          0.466005  0.460000  default   average             NaN
# 28          0.459079  0.525000  default   average             NaN
# 29          0.466005  0.464789  default   average             NaN
# 30          0.339752  0.753578  default       NaN             0.1
# 31          0.432129  0.839662  default       NaN             0.1
# 32          0.298083  0.558841  default       NaN             0.1
# 33          0.432129  0.629747  default       NaN             0.1
# 34          0.298083  0.559324  default       NaN             0.1
# 35          0.429951  0.698534  default       NaN             0.3
# 36          0.432129  0.839662  default       NaN             0.3
# 37          0.455819  0.693541  default       NaN             0.3
# 38          0.432129  0.629747  default       NaN             0.3
# 39          0.455819  0.866926  default       NaN             0.3
# 40          0.359039  0.626382  default       NaN             0.5
# 41          0.557979  0.518072  default       NaN             0.5
# 42          0.409671  0.611263  default       NaN             0.5
# 43          0.557979  0.388554  default       NaN             0.5
# 44          0.409671  0.764078  default       NaN             0.5
# 45          0.424534  0.424000  default       NaN             0.7
# 46          0.459874  0.657277  default       NaN             0.7
# 47          0.412401  0.416000  default       NaN             0.7
# 48          0.459874  0.520000  default       NaN             0.7
# 49          0.412401  0.485915  default       NaN             0.7
# 50          0.359442  0.404000  default       NaN             0.9
# 51          0.420871  0.664319  default       NaN             0.9
# 52          0.370102  0.404000  default       NaN             0.9
# 53          0.420871  0.505000  default       NaN             0.9
# 54          0.370102  0.496479  default       NaN             0.9

# %%
ce.evaluate_single_method('sipu', 'compound', 'dbscan', plot=True, eps=0.2, min_samples=7)
display(ce.results_df)
display(ce.results_df[ce.results_df['eps'] == 0.2])
# Out:
#    battery   dataset         method   labels  n_clusters  rand_score  \
# 0     sipu  compound         kmeans  labels0           6    0.539721
# 1     sipu  compound         kmeans  labels1           4    0.783095
# 2     sipu  compound         kmeans  labels2           5    0.486942
# 3     sipu  compound         kmeans  labels3           4    0.596352
# 4     sipu  compound         kmeans  labels4           5    0.835282
# 5     sipu  compound         dbscan  labels0           6    0.436617
# 6     sipu  compound         dbscan  labels1           4    0.584192
# 7     sipu  compound         dbscan  labels2           5    0.436478
# 8     sipu  compound         dbscan  labels3           4    0.476249
# 9     sipu  compound         dbscan  labels4           5    0.543696
# 10    sipu  compound  agglomerative  labels0           6    0.551803
# 11    sipu  compound  agglomerative  labels1           4    0.879290
# 12    sipu  compound  agglomerative  labels2           5    0.586619
# 13    sipu  compound  agglomerative  labels3           4    0.737443
# 14    sipu  compound  agglomerative  labels4           5    0.762757
# 15    sipu  compound  agglomerative  labels0           6    0.742481
# 16    sipu  compound  agglomerative  labels1           4    0.925356
# 17    sipu  compound  agglomerative  labels2           5    0.741496
# 18    sipu  compound  agglomerative  labels3           4    0.794270
# 19    sipu  compound  agglomerative  labels4           5    0.871486
# 20    sipu  compound  agglomerative  labels0           6    0.792878
# 21    sipu  compound  agglomerative  labels1           4    0.851878
# 22    sipu  compound  agglomerative  labels2           5    0.796298
# 23    sipu  compound  agglomerative  labels3           4    0.828137
# 24    sipu  compound  agglomerative  labels4           5    0.757881
# 25    sipu  compound  agglomerative  labels0           6    0.803026
# 26    sipu  compound  agglomerative  labels1           4    0.909666
# 27    sipu  compound  agglomerative  labels2           5    0.765497
# 28    sipu  compound  agglomerative  labels3           4    0.798372
# 29    sipu  compound  agglomerative  labels4           5    0.803169
# 30    sipu  compound          genie  labels0           6    0.565935
# 31    sipu  compound          genie  labels1           4    0.775595
# 32    sipu  compound          genie  labels2           5    0.521087
# 33    sipu  compound          genie  labels3           4    0.611531
# 34    sipu  compound          genie  labels4           5    0.569824
# 35    sipu  compound          genie  labels0           6    0.541257
# 36    sipu  compound          genie  labels1           4    0.775595
# 37    sipu  compound          genie  labels2           5    0.583866
# 38    sipu  compound          genie  labels3           4    0.611531
# 39    sipu  compound          genie  labels4           5    0.760048
# 40    sipu  compound          genie  labels0           6    0.607345
# 41    sipu  compound          genie  labels1           4    0.879882
# 42    sipu  compound          genie  labels2           5    0.703997
# 43    sipu  compound          genie  labels3           4    0.738108
# 44    sipu  compound          genie  labels4           5    0.856762
# 45    sipu  compound          genie  labels0           6    0.754603
# 46    sipu  compound          genie  labels1           4    0.913517
# 47    sipu  compound          genie  labels2           5    0.747218
# 48    sipu  compound          genie  labels3           4    0.797245
# 49    sipu  compound          genie  labels4           5    0.847201
# 50    sipu  compound          genie  labels0           6    0.742481
# 51    sipu  compound          genie  labels1           4    0.925356
# 52    sipu  compound          genie  labels2           5    0.741496
# 53    sipu  compound          genie  labels3           4    0.794270
# 54    sipu  compound          genie  labels4           5    0.871486
# 55    sipu  compound         dbscan  labels0           6    0.877279
# 56    sipu  compound         dbscan  labels1           4    0.728128
# 57    sipu  compound         dbscan  labels2           5    0.874815
# 58    sipu  compound         dbscan  labels3           4    0.827006
# 59    sipu  compound         dbscan  labels4           5    0.770806
#
#     silhouette_score       NCA   params   linkage  gini_threshold  eps  \
# 0           0.430090  0.673607  default       NaN             NaN  NaN
# 1           0.455494  0.530516  default       NaN             NaN  NaN
# 2           0.396344  0.485488  default       NaN             NaN  NaN
# 3           0.499777  0.511381  default       NaN             NaN  NaN
# 4           0.488060  0.705986  default       NaN             NaN  NaN
# 5           0.638323  0.200000  default       NaN             NaN  NaN
# 6           0.638323  0.333333  default       NaN             NaN  NaN
# 7           0.638323  0.200000  default       NaN             NaN  NaN
# 8           0.638323  0.250000  default       NaN             NaN  NaN
# 9           0.638323  0.250000  default       NaN             NaN  NaN
# 10          0.417080  0.737789  default      ward             NaN  NaN
# 11          0.549850  0.502008  default      ward             NaN  NaN
# 12          0.509396  0.697756  default      ward             NaN  NaN
# 13          0.549850  0.376506  default      ward             NaN  NaN
# 14          0.509396  0.872195  default      ward             NaN  NaN
# 15          0.359442  0.404000  default    single             NaN  NaN
# 16          0.420871  0.664319  default    single             NaN  NaN
# 17          0.370102  0.404000  default    single             NaN  NaN
# 18          0.420871  0.505000  default    single             NaN  NaN
# 19          0.370102  0.496479  default    single             NaN  NaN
# 20          0.453223  0.460000  default  complete             NaN  NaN
# 21          0.476368  0.615023  default  complete             NaN  NaN
# 22          0.458974  0.488000  default  complete             NaN  NaN
# 23          0.476368  0.610000  default  complete             NaN  NaN
# 24          0.458974  0.440141  default  complete             NaN  NaN
# 25          0.460774  0.642222  default   average             NaN  NaN
# 26          0.459079  0.654930  default   average             NaN  NaN
# 27          0.466005  0.460000  default   average             NaN  NaN
# 28          0.459079  0.525000  default   average             NaN  NaN
# 29          0.466005  0.464789  default   average             NaN  NaN
# 30          0.339752  0.753578  default       NaN             0.1  NaN
# 31          0.432129  0.839662  default       NaN             0.1  NaN
# 32          0.298083  0.558841  default       NaN             0.1  NaN
# 33          0.432129  0.629747  default       NaN             0.1  NaN
# 34          0.298083  0.559324  default       NaN             0.1  NaN
# 35          0.429951  0.698534  default       NaN             0.3  NaN
# 36          0.432129  0.839662  default       NaN             0.3  NaN
# 37          0.455819  0.693541  default       NaN             0.3  NaN
# 38          0.432129  0.629747  default       NaN             0.3  NaN
# 39          0.455819  0.866926  default       NaN             0.3  NaN
# 40          0.359039  0.626382  default       NaN             0.5  NaN
# 41          0.557979  0.518072  default       NaN             0.5  NaN
# 42          0.409671  0.611263  default       NaN             0.5  NaN
# 43          0.557979  0.388554  default       NaN             0.5  NaN
# 44          0.409671  0.764078  default       NaN             0.5  NaN
# 45          0.424534  0.424000  default       NaN             0.7  NaN
# 46          0.459874  0.657277  default       NaN             0.7  NaN
# 47          0.412401  0.416000  default       NaN             0.7  NaN
# 48          0.459874  0.520000  default       NaN             0.7  NaN
# 49          0.412401  0.485915  default       NaN             0.7  NaN
# 50          0.359442  0.404000  default       NaN             0.9  NaN
# 51          0.420871  0.664319  default       NaN             0.9  NaN
# 52          0.370102  0.404000  default       NaN             0.9  NaN
# 53          0.420871  0.505000  default       NaN             0.9  NaN
# 54          0.370102  0.496479  default       NaN             0.9  NaN
# 55          0.443863  0.745614   custom       NaN             NaN  0.2
# 56          0.443863  0.396374   custom       NaN             NaN  0.2
# 57          0.443863  0.740723   custom       NaN             NaN  0.2
# 58          0.443863  0.601506   custom       NaN             NaN  0.2
# 59          0.443863  0.621678   custom       NaN             NaN  0.2
#
#     min_samples
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 38          NaN
# 39          NaN
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44          NaN
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN
# 50          NaN
# 51          NaN
# 52          NaN
# 53          NaN
# 54          NaN
# 55          7.0
# 56          7.0
# 57          7.0
# 58          7.0
# 59          7.0
#    battery   dataset  method   labels  n_clusters  rand_score  \
# 55    sipu  compound  dbscan  labels0           6    0.877279
# 56    sipu  compound  dbscan  labels1           4    0.728128
# 57    sipu  compound  dbscan  labels2           5    0.874815
# 58    sipu  compound  dbscan  labels3           4    0.827006
# 59    sipu  compound  dbscan  labels4           5    0.770806
#
#     silhouette_score       NCA  params linkage  gini_threshold  eps  \
# 55          0.443863  0.745614  custom     NaN             NaN  0.2
# 56          0.443863  0.396374  custom     NaN             NaN  0.2
# 57          0.443863  0.740723  custom     NaN             NaN  0.2
# 58          0.443863  0.601506  custom     NaN             NaN  0.2
# 59          0.443863  0.621678  custom     NaN             NaN  0.2
#
#     min_samples
# 55          7.0
# 56          7.0
# 57          7.0
# 58          7.0
# 59          7.0

# %%
ce.save_results(filename="results.csv")
# Out:
# Results saved to results.csv
