# %%
# add parent directory to path
import sys
import os

# Get the absolute path of the notebook's directory
notebook_dir = os.path.dirname(os.path.abspath("__file__"))
# Get the parent directory (project root)
project_root = os.path.dirname(notebook_dir)

# Add the project root to Python path if it's not already there
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    print(f"Added {project_root} to Python path")

print(f"Current Python path: {sys.path}")

import clustbench
from evaluate import ClusteringEvaluator
# %load_ext autoreload
# %autoreload 2

# %%
data_path = os.path.join("..", "clustering-data-v1")
data_path = os.path.abspath(data_path)
data_path

battery = "sipu"
print(
    f"Dataset names for battery '{battery}': {clustbench.get_dataset_names(battery, path=data_path)}"
)

# %%
ce = ClusteringEvaluator(data_path=data_path)
display(ce.results_df)

# %% [markdown]
# # a1/2/3

# %%
ce.do_all("sipu", "a1", plot=True)
display(ce.results_df)

# %%
ce.evaluate_single_method(
    battery="sipu",
    dataset="a1",
    method="dbscan",
    plot=True,
    eps=0.07,
    min_samples=10,
)
display(ce.results_df[ce.results_df["dataset"] == "a1"])

# %%
display(ce.results_df)

# %%
ce.do_all("sipu", "a2", plot=True)
display(ce.results_df[ce.results_df["dataset"] == "a2"])

# %%
ce.do_all("sipu", "a3", plot=True)
display(ce.results_df[ce.results_df["dataset"] == "a3"])

# %%
ce.save_results()

# %% [markdown]
# # aggregation

# %%
ce.do_all("sipu", "aggregation", plot=True)
display(ce.results_df[ce.results_df["dataset"] == "aggregation"])

# %%
ce.evaluate_single_method(
    battery="sipu",
    dataset="aggregation",
    method="dbscan",
    plot=True,
    eps=0.15,
    min_samples=5,
)
display(ce.results_df[ce.results_df["dataset"] == "aggregation"])

# %%
ce.evaluate_single_method(
    battery="sipu",
    dataset="aggregation",
    method="dbscan",
    plot=True,
    eps=0.15,
    min_samples=8,
)
display(ce.results_df[ce.results_df["dataset"] == "aggregation"])

# %%
ce.save_results()

# %% [markdown]
# # compound

# %%
ce.do_all("sipu", "compound", plot=True)
display(ce.results_df[ce.results_df["dataset"] == "compound"])

# %%
ce.evaluate_single_method(
    battery="sipu",
    dataset="compound",
    method="dbscan",
    plot=True,
    eps=0.15,
    min_samples=5,
)
display(ce.results_df[ce.results_df["dataset"] == "compound"])

# %%
ce.evaluate_single_method(
    battery="sipu",
    dataset="compound",
    method="dbscan",
    plot=True,
    eps=0.2,
    min_samples=5,
)
display(ce.results_df[ce.results_df["dataset"] == "compound"])

# %%
ce.save_results()

# %% [markdown]
# # d31

# %%
ce.do_all("sipu", "d31", plot=True)
display(ce.results_df[ce.results_df["dataset"] == "d31"])

# %%
ce.save_results()

# %% [markdown]
# # flame

# %%
ce.do_all("sipu", "flame", plot=True)
display(ce.results_df[ce.results_df["dataset"] == "flame"])

# %%
ce.evaluate_single_method(
    battery="sipu",
    dataset="flame",
    method="dbscan",
    plot=True,
    eps=0.1,
    min_samples=8,
)
display(ce.results_df[ce.results_df["dataset"] == "flame"])

# %%
ce.evaluate_single_method(
    battery="sipu",
    dataset="flame",
    method="dbscan",
    plot=True,
    eps=0.1,
    min_samples=5,
)
display(ce.results_df[ce.results_df["dataset"] == "flame"])

# %%
ce.evaluate_single_method(
    battery="sipu",
    dataset="flame",
    method="dbscan",
    plot=True,
    eps=0.15,
    min_samples=8,
)
display(ce.results_df[ce.results_df["dataset"] == "flame"])

# %%
ce.save_results()

# %% [markdown]
# # jain

# %%
ce.do_all("sipu", "jain", plot=True)
display(ce.results_df[ce.results_df["dataset"] == "jain"])

# %%
ce.save_results()

# %% [markdown]
# # pathbased

# %%
ce.do_all("sipu", "pathbased", plot=True)
display(ce.results_df[ce.results_df["dataset"] == "pathbased"])

# %%
ce.save_results()

# %% [markdown]
# # r15

# %%
ce.do_all("sipu", "r15", plot=True)
display(ce.results_df[ce.results_df["dataset"] == "r15"])

# %%
ce.save_results()

# %% [markdown]
# # s1/2/3/4

# %%
ce.do_all("sipu", "s1", plot=True)
display(ce.results_df[ce.results_df["dataset"] == "s1"])

# %%
ce.do_all("sipu", "s2", plot=True)
display(ce.results_df[ce.results_df["dataset"] == "s2"])

# %%
ce.do_all("sipu", "s3", plot=True)
display(ce.results_df[ce.results_df["dataset"] == "s3"])

# %%
ce.do_all("sipu", "s4", plot=True)
display(ce.results_df[ce.results_df["dataset"] == "s4"])

# %%
ce.save_results()

# %% [markdown]
# # spiral

# %%
ce.do_all("sipu", "spiral", plot=True)
display(ce.results_df[ce.results_df["dataset"] == "spiral"])

# %%
ce.save_results()

# %% [markdown]
# # unbalance

# %%
ce.do_all("sipu", "unbalance", plot=True)
display(ce.results_df[ce.results_df["dataset"] == "unbalance"])

# %%
ce.save_results()
